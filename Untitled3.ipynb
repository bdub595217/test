# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('c:/Users/595217/Downloads/Men_Rx_2018')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187876 entries, 0 to 187875
# Data columns (total 35 columns):
# User_id                187876 non-null int64
# Name                   187876 non-null object
# Height_(m)             132252 non-null float64
# Weight_(kg)            149130 non-null float64
# Age                    187876 non-null int64
# Region_id              187876 non-null int64
# Region_name            187876 non-null object
# Affiliate_id           187876 non-null int64
# Overall_rank           187876 non-null int64
# Overall_score          187876 non-null int64
# Overall_percentile     187876 non-null float64
# 18.1_rank              187876 non-null int64
# 18.1_score             168298 non-null object
# 18.1_percentile        168298 non-null float64
# 18.2_rank              187876 non-null int64
# 18.2_score             170272 non-null object
# 18.2_percentile        170272 non-null float64
# 18.2_predicted_time    170272 non-null timedelta64[ns]
# ...

# %%
df.describe()
# Out:
#             User_id     Height_(m)    Weight_(kg)            Age  \
# count  1.878760e+05  132252.000000  149130.000000  187876.000000
# mean   8.249805e+05       1.784462      85.231047      33.335237
# std    4.190617e+05       0.811885      42.352651       7.737016
# min    1.000000e+00       0.010000       0.000000      16.000000
# 25%    4.867525e+05       1.740000      77.000000      28.000000
# 50%    9.024820e+05       1.780000      84.000000      33.000000
# 75%    1.224221e+06       1.830000      91.000000      38.000000
# max    1.438629e+06     183.180000   15467.000000      54.000000
#
#            Region_id   Affiliate_id   Overall_rank  Overall_score  \
# count  187876.000000  187876.000000  187876.000000   1.878760e+05
# mean       17.570877    9294.154719   94759.956067   5.702040e+05
# std         6.324736    6350.874625   55617.474637   2.861698e+05
# min         5.000000       0.000000       1.000000   9.800000e+01
# ...

# %%
df.corr()
# Out:
#                       User_id  Height_(m)  Weight_(kg)       Age  Region_id  \
# User_id              1.000000    0.001027    -0.017088 -0.196144   0.145052
# Height_(m)           0.001027    1.000000     0.015340  0.000219   0.004909
# Weight_(kg)         -0.017088    0.015340     1.000000  0.040929  -0.046250
# Age                 -0.196144    0.000219     0.040929  1.000000  -0.118750
# Region_id            0.145052    0.004909    -0.046250 -0.118750   1.000000
# Affiliate_id         0.149014    0.002922    -0.007714 -0.060432   0.166721
# Overall_rank         0.405326    0.000518     0.031799  0.194642   0.020122
# Overall_score        0.411952    0.000580     0.030222  0.201285   0.022173
# Overall_percentile  -0.407924   -0.000538    -0.031474 -0.197522  -0.020925
# 18.1_rank            0.369762   -0.006605     0.016391  0.181417   0.037897
# 18.1_percentile     -0.337430    0.006691     0.000468 -0.204606  -0.041699
# ...

# %%
df2 = pd.read_pickle('c:/Users/595217/Downloads/Men_Sc_2018')

# %%
df2.corr()
# Out:
#                       User_id  Height_(m)  Weight_(kg)       Age  Region_id  \
# User_id              1.000000    0.001800    -0.085258 -0.251899   0.141976
# Height_(m)           0.001800    1.000000     0.081674 -0.007340  -0.004053
# Weight_(kg)         -0.085258    0.081674     1.000000  0.163223  -0.234311
# Age                 -0.251899   -0.007340     0.163223  1.000000  -0.197918
# Region_id            0.141976   -0.004053    -0.234311 -0.197918   1.000000
# Affiliate_id         0.151555   -0.010821    -0.044764 -0.097910   0.171730
# Overall_rank         0.143856   -0.007799     0.087975  0.001438  -0.062032
# Overall_score        0.147917   -0.005289     0.087512  0.007666  -0.062739
# Overall_percentile  -0.143856    0.007799    -0.087975 -0.001438   0.062032
# 18.1_rank            0.085321   -0.036014    -0.053938 -0.013344  -0.016587
# 18.1_percentile     -0.094645    0.032237     0.043982 -0.002120   0.021325
# ...
